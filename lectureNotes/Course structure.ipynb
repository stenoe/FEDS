# %% [markdown]
# ### Course Structure
#
# #### 1.	Course overview / motivation
#
# #### 2.	Introduction to Python
#
#     2.1	Jupyter Notebook overview
#     2.2	First program
#     2.3	Data types (int, float, bool, str, list, tuple, set, dict)
#     2.4	Numbers (int, float)
#     2.5	Math Functions
#     2.6	Operators
#     2.7	Variables
#     2.8	Expression vs statement
#     2.9	Assignment operators
#     2.10	Strings and string operations
#     2.11	Data types conversion
#     2.12	Strings specials
#     2.13	Indexing
#     2.14	Built-in functions and methods
#     2.15	Booleans and operations
#     2.16	Script writing fundamentals
#     2.17	Lists and lists operations, methods, slicing
#     2.18	None
#     2.19	Dictionaries and dictionaries operations, methods
#     2.20	Tuples and tuples operations, methods
#     2.21	Sets and sets operations, methods
#     2.22	Conditional logic and logical Operators
#     2.23	Loops: for, while
#     2.24	Loops management
#     2.25	Range and enumerate
#     2.26	Functions:
#         1.	Fundamentals
#         2.	Parameters and arguments
#         3.	Return
#         4.	Docstrings
#         5.	args and kwards
#         6.	Scope: local vs global
#         7.	Pure functions
#     2.27	Map(), filter(), zip(), reduce()
#     2.28	Modules, packages
#
# #### 3.	Environment setup
#     3.1	Mac
#     3.2	Wind
#     3.3	Linux
# #### 4.	NumPy
#     4.1	What is NumPy
#     4.2	Anatomy of NumPy
#     4.3	NP datatypes and attributes
#     4.4	Creating NP array
#     4.5	Np.ones
#     4.6	Np.zeros
#     4.7	Np.array
#     4.8	Random seed
#     4.9	Np.arrays viewing and slicing
#     4.10	Arrays manipulation
#     4.11	Basic statistics
#     4.12	Reshaping transposing
#     4.13	Dot product vs element wise operations
#     4.14	Comparison, sorting
#     4.15	Object to array conversion
# #### 5.	Pandas
#     5.1	What is pandas
#     5.2	Anatomy on Pandas
#     5.3	Pandas data
#     5.4	Get basic info about data: info(), describe(), dtypes()
#     5.6	Selection and viewing data
#     5.7	Data manipulation
#     5.8	Indexing
#     5.9	Multiindexing
#     5.10	Datatime basics
#     5.11	Pandas plotting
#     5.12	Data sharing
#     5.13	Csv
#     5.14	Pickle
#     5.15	Crossplatform sharing
# #### 6.	Matplotlib
#     6.1	What is matplotlib
#     6.2	Anatomy of Matplotlib
#     6.3	Plotting workflow
#     6.4	Two types of plotting
#     6.5	Basic figures:
#     6.6	Scatter
#     6.7	Bar
#     6.8	Histogram
#     6.9	Subplots
#     6.10	Plotting with NumPy
#     6.11	Plotting with Pandas
#     6.12	Customization:
#     6.13	Title
#     6.14	Labels
#     6.15	Legend
#     6.16	Style
#     6.17	Export
# #### 7.	Basic statistics
# #### 8.	Skit-learn
# #### 9.	TensorFlow
